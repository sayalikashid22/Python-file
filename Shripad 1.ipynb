# %%
cource="Data science"
type(cource)
# Out:
# str

# %%
dir(str)     #dender function
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
cource.capitalize()
# Out:
# 'Data science'

# %%
Drama="penthouse"
Drama.capitalize()
# Out:
# 'Penthouse'

# %%
Drama.upper()
# Out:
# 'PENTHOUSE'

# %%
Drama.lower()
# Out:
# 'penthouse'

# %%
Drama.title()
# Out:
# 'Penthouse'

# %%
food="paneer butter masala"
food.title()
# Out:
# 'Paneer Butter Masala'

# %%
Drama.casefold()
# Out:
# 'penthouse'

# %%
snax="MaGGi"
snax.swapcase()
# Out:
# 'mAggI'

# %%
dialogue="My name is sau"
dialogue.split()
# Out:
# ['My', 'name', 'is', 'sau']

# %%
movie="Mumbai-Pune-Mumbai"
movie.split("-")
# Out:
# ['Mumbai', 'Pune', 'Mumbai']

# %%
mail_id ="sayalikashod650@gmail.com"
mail_id.split("@")
# Out:
# ['sayalikashod650', 'gmail.com']

# %%
dialogue.replace("sau","sayali")
# Out:
# 'My name is sayali'

# %%
name="sayaaloooo"
name.count("o")
# Out:
# 4

# %%
"saaayalooo".count('a')    #direct use count function
# Out:
# 4

# %%
city="Pune"    #repetition
city*4
# Out:
# 'PunePunePunePune'

# %%
name="sayali"    #Concatenation
lname="kashid"
name+lname
# Out:
# 'sayalikashid'

# %%
name+' '+lname
# Out:
# 'sayali kashid'

# %%
salary=14000

if salary>20000:
    tax=0.25
    peint("Hello")
else:
    tax=0.20
    print("welcome")
    
net_salary = salary-tax*salary
net_salary
# Out:
# welcome
# 11200.0

# %%
for number in range(5,10):
    print (number)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for number in range(5,11):
    print (number)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
for num in range(11):
    print(num,num*num)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100

# %%
city ="pune"

for ch in city:
    print(ch)
# Out:
# p
# u
# n
# e

# %%
food="pizza"

for val in range(3,6):
    print(food * val)
# Out:
# pizzapizzapizza
# pizzapizzapizzapizza
# pizzapizzapizzapizzapizza

# %%
#range(satrt,stop,step)
#end give output on single line

for i in range(5,40,3):
    print(i,end=' ')
# Out:
# 5 8 11 14 17 20 23 26 29 32 35 38

# %%
for letter in "sAyAlI":
     print(letter.swapcase(),end='')
# Out:
# SaYaLi

# %%
for ch in "Data science":
    print (ch * 4,end=' ')
# Out:
# DDDD aaaa tttt aaaa      ssss cccc iiii eeee nnnn cccc eeee

# %%
for ch in "Data science":
    print (4 * ch,end=' ')
# Out:
# DDDD aaaa tttt aaaa      ssss cccc iiii eeee nnnn cccc eeee

# %%
len("sayali")
# Out:
# 6

# %%
marks=[23,64,37,86,56]
marks
# Out:
# [23, 64, 37, 86, 56]

# %%
#create another sorted list and oroginal list remain uncangw
marks=sorted(marks) 
marks
# Out:
# [23, 37, 56, 64, 86]

# %%
#modifies original list
marks.sort()
marks
# Out:
# [23, 37, 56, 64, 86]

# %%
marks.append(92)    #add
marks
# Out:
# [23, 37, 56, 64, 86, 92]

# %%
marks.count(92)
# Out:
# 1

# %%
marks.reverse()
marks
# Out:
# [92, 86, 64, 56, 37, 23]

# %%
marks.sort (reverse=True)   #accending order
marks
# Out:
# [92, 86, 64, 56, 37, 23]

# %%
64 in marks  #precent or Not
# Out:
# True

# %%
55 in marks
# Out:
# False

# %%
l1=[10,20,30]   #concatation
l2=[40,50,60]
l1+l2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
(l1+l2)*3
# Out:
# [10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60]

# %%
mylist=["Apple","Mango","Orange","Strawberry","watermelon","blueberry","Banana","Blackberry"]
mylist
# Out:
# ['Apple',
#  'Mango',
#  'Orange',
#  'Strawberry',
#  'watermelon',
#  'blueberry',
#  'Banana',
#  'Blackberry']

# %%
for fruit in mylist:
    print(fruit.upper(),end=' ')
# Out:
# APPLE MANGO ORANGE STRAWBERRY WATERMELON BLUEBERRY BANANA BLACKBERRY

# %%
for fruit in mylist:
    print(fruit.replace('a','u'),end=' ')
# Out:
# Apple Mungo Orunge Struwberry wutermelon blueberry Bununu Bluckberry

# %%
'put'in 'computer'
# Out:
# True

# %%
'cut'in 'computer'
# Out:
# False

# %%
mylist
# Out:
# ['Apple',
#  'Mango',
#  'Orange',
#  'Strawberry',
#  'watermelon',
#  'blueberry',
#  'Banana',
#  'Blackberry']

# %%
for fruit in mylist:
    if 'berry'in fruit:
        print(fruit)
# Out:
# Strawberry
# blueberry
# Blackberry

# %%
newfruits=[]
for fruit in mylist:
    if 'berry'in fruit:
        newfruits.append(fruit)
newfruits
# Out:
# ['Strawberry', 'blueberry', 'Blackberry']

# %%
newfruits=[]
newfruits1=[]
for fruit in mylist:
    if 'berry'in fruit:
        newfruits.append(fruit)
    else:
        newfruits1.append(fruit)
        
print(newfruits)
newfruits1
# Out:
# ['Strawberry', 'blueberry', 'Blackberry']
# ['Apple', 'Mango', 'Orange', 'watermelon', 'Banana']

# %%
numbers=[4,7,3,5,9]
list=[]
for num in numbers:
    list.append(num**2)
list
# Out:
# [16, 49, 9, 25, 81]

# %%
#list comprehension

numbers=[4,7,3,5,9]
list=[num**2 for num in numbers]
list
# Out:
# [16, 49, 9, 25, 81]

# %%
[fruit for fruit in mylist if 'berry' in fruit]
# Out:
# ['Strawberry', 'blueberry', 'Blackberry']

# %%
[fruit for fruit in mylist if not 'berry' in fruit]
# Out:
# ['Apple', 'Mango', 'Orange', 'watermelon', 'Banana']

# %%
mylist
mylist.index('Banana')
# Out:
# 6

# %%
mylist[2]='Guava'
mylist
# Out:
# ['Apple',
#  'Mango',
#  'Guava',
#  'Strawberry',
#  'watermelon',
#  'blueberry',
#  'Banana',
#  'Blackberry']

# %%
#dictionary (key value pair)

mydict={42:'mouse',21:'keyboard',77:'Moniter',71:'Earphone'}
mydict
# Out:
# {42: 'mouse', 21: 'keyboard', 77: 'Moniter', 71: 'Earphone'}

# %%
mydict[21]
# Out:
# 'keyboard'

# %%
dir(mydict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
mydict.keys()
# Out:
# dict_keys([42, 21, 77, 71])

# %%
mydict.items()
# Out:
# dict_items([(42, 'mouse'), (21, 'keyboard'), (77, 'Moniter'), (71, 'Earphone')])

# %%
mydict.values()
# Out:
# dict_values(['mouse', 'keyboard', 'Moniter', 'Earphone'])

# %%
newdict={'A':mylist,'b':numbers,'c':marks}
newdict
# Out:
# {'A': ['Apple',
#   'Mango',
#   'Guava',
#   'Strawberry',
#   'watermelon',
#   'blueberry',
#   'Banana',
#   'Blackberry'],
#  'b': [4, 7, 3, 5, 9],
#  'c': [92, 86, 64, 56, 37, 23]}

# %%
newdict['A']
# Out:
# ['Apple',
#  'Mango',
#  'Guava',
#  'Strawberry',
#  'watermelon',
#  'blueberry',
#  'Banana',
#  'Blackberry']

# %%
newdict['A'][3]
# Out:
# 'Strawberry'

# %%
newdict['c'][2]
# Out:
# 64

# %%
from math import sqrt,log,exp,sin    #import as indivisualor specific fun
sqrt(37)
# Out:
# 6.082762530298219

# %%
log(37)
# Out:
# 3.6109179126442243

# %%
from math import*    #import everything fun
cos(0.26)
# Out:
# 0.9663899781345132

# %%
import math
math.sqrt(37)
# Out:
# 6.082762530298219

# %%
math.log(37)
# Out:
# 3.6109179126442243

# %%
import math as mt   #alias like nickname of fun
mt.exp(98)
# Out:
# 3.637970947608805e+42

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/user/Desktop/Data Science/Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df=pd.read_csv('Salaries.csv')
df

# %%
df.head()

# %%
df.tail()

# %%
df.head(5)

# %%
df.tail(9)

# %%
df.info()

# %%
df.describe()

# %%
df.salary.mean()

# %%
df.salary.max()

# %%
df.salary

# %%
df['salary']

# %%
df['rank']

# %%
df.count()

# %%
df.groupby(['rank']).mean()

# %%
df.groupby(['rank']).count()

# %%
df.groupby(['discipline','rank']).count()

# %%
df.groupby(['discipline','rank']).mean()

# %%
df.groupby('rank')[['salary']].mean()

# %%
df.groupby(['discipline','rank','sex']).mean()

# %%
df.groupby('rank')[['salary','phd']].mean()

# %%
df.groupby('rank')[['salary','phd']].describe()

# %%
df.groupby('rank')[['salary','phd']].max()

# %%
df['salary']

# %%
df1=df[df['salary']>120000]
df1

# %%
df2=df[df['phd']<50]
df2

# %%
df5=df[df.salary>150000]   #the another way  #use all arithmetic fun
df5

# %%
df.mean()

# %%
df.shape

# %%
df.shape[0]

# %%
df.shape[1]

# %%
df5=df[df.salary>150000].shape[0]   
df5

# %%
newdf=df[(df['sex']=='Male') & (df['salary']>150000)]
newdf

# %%
newdf.shape[0]

# %%
df7=df[df['rank']!='Prof']
df7

# %%
df7=df[df['rank']!='Prof'].shape[0]
df7

# %%
newdf1=df[(df['sex']=='female')|(df['service']>10)]
newdf1

# %%
df

# %%
df.iloc[3]

# %%
df.iloc[25:30,]   #[condition for row,condition columns]

# %%
df.iloc[25:30]

# %%
df.iloc[:,2:5]

# %%
df.iloc[51:57,4:6]

# %%
df.iloc[[12,35,47,55]]    #seperat the row

# %%
df.loc[:,['rank','sex']]     #speparate colunms by use only loc

# %%
df.loc[:,['rank','salary']]

# %%
df.loc[[24,56,71],['rank','salary']]

# %%
df.iloc[::5]   #:=start,:stop,:step

# %%
df.iloc[34:51:3]

# %%
df.iloc[::-1]

# %%
df.iloc[[5,2],[1,3]]

# %%
df.iloc[:,-1]

# %%
df[['salary','rank']].agg(['min','max','mean'])

# %%
df['rank'].value_counts().plot.bar()

# %%
df['rank'].value_counts().plot.line()

# %%
import matplotlib.pyplot as plt

# %%
marks= [64,92,47,58,71]
salary= [24000,61000,8000,14000,19000]
plt.scatter(marks,salary,color='red')

# %%
marks= [64,92,47,58,71]
salary= [24000,61000,8000,14000,19000]
plt.scatter(marks,salary,color='red')
plt.xlabel('Marks of students')
plt.ylabel('salaries of student')
plt.title('Salary Distribution of students')

# %%
x=[-4,-1,3,5,8,10]
y=[39,61,27,84,55,98]
plt.figure(figsize=(10,7))
plt.plot(x,y)
plt.xlabel('Values of x')
plt.ylabel('Values of y')
plt.title('Demo graph')
plt.suptitle('Learning Data Science',size=25)

# %%
x=[-4,-1,3,5,8,10]
y=[39,61,27,84,55,98]
plt.figure(figsize=(10,5))
plt.plot(x,y)
plt.xlabel('Values of x')
plt.ylabel('Values of y')
plt.title('Demo graph')
plt.suptitle('Learning Data Science',size=25)
plt.xlim(-20,20)
plt.ylim(25,100)

# %%
y = ([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
x= (range(-100,101))
y=[i**2 for i in x]
plt.plot(x,y,color='red')
plt.xlabel('Values of x')
plt.ylabel('Values of y')
plt.title('Demo graph')

# %%
x= (range(1,50))
y=[exp(i) for i in x]
plt.plot(x,y,color='yellow')
plt.xlabel('Values of x')
plt.ylabel('Values of y')
plt.title('exponential graph')

# %%
x= (range(1,100))
y=[log(i) for i in x]
plt.plot(x,y)
plt.xlabel('Values of x')
plt.ylabel('Values of y')
plt.title('logarithum graph')

# %%
from math import*

# %%
plt.figure(figsize=(16,9))

x=(range(-10,11))

y=[i**2 for i in x]
plt.subplot(3,4,1)
plt.plot(x,y)
plt.title("Graph of x**2")

y=[i**3 for i in x]
plt.subplot(3,4,10)
plt.plot(x,y)
plt.title("Graph of x**3")

y=[cos(i) for i in x]
plt.subplot(3,4,5)
plt.plot(x,y)
plt.title("Graph of x**5")

y=[sin(i) for i in x]
plt.subplot(3,4,8)
plt.plot(x,y)
plt.title("Graph of sign")

y=[exp(i) for i in x]
plt.subplot(3,4,3)
plt.plot(x,y)
plt.title("Graph of log")

# %%
data=pd.read_csv('C:/Users/user/Desktop/Data Science/mtcars.csv')
data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
data.shape

# %%
data.columns

# %%
pd.crosstab(data['cyl'],data['gear'])

# %%
pd.crosstab(data['cyl'],data['gear']).plot (kind='bar')

# %%
data["gear"].value_counts()

# %%
data.gear.value_counts().plot(kind="pie")

# %%
#scatter plot og two variable

plt.scatter(data.mpg,data.qsec,color="limegreen")

plt.xlabel("mpg")
plt.xlabel("qsec")
plt.title("mpg vs qsec")

# %%
#Histogram
plt.hist(data['mpg'],edgecolor="yellow")

# %%
plt.hist(data['mpg'],facecolor="red",edgecolor="green",bins=6)

# %%
#Boxplot

plt.boxplot(data['mpg'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.boxplot(data['mpg'],vert = False, notch = True)
plt.xlabel("MPG")
plt.ylabel("Boxplot")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
plt.boxplot(data['mpg'],vert = False)
plt.xlabel("MPG")
plt.ylabel("Boxplot")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
sns.violinplot(data['mpg'])   #violin plt
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
sns.violinplot(data['mpg'],orient = "v")   #vertical
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='mpg'>

# %%
sns.violinplot(data['mpg'],orient = "h")    #horizontal
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
sns.violinplot(data['mpg'],data['cyl'],palette="muted")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg', ylabel='cyl'>

# %%
sns.violinplot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
help(sns.load_dataset('tips'))
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order. If a dict contains Series
#  |      which have an index defined, it is aligned by its index.
#  |
# ...

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
pd.crosstab(tips['smoker'],tips['sex'])
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
pd.crosstab(tips['smoker'],tips['sex']).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
sns.stripplot(y="tip",data=tips,jitter=True)
plt.ylabel("tip($)")
plt.show()

# %%
sns.stripplot(y="tip",data=tips,jitter=False)
plt.ylabel("tip($)")
plt.show()

# %%
sns.stripplot(x= 'day',y="tip",data=tips,jitter=True)
plt.ylabel("tip($)")
plt.show()

# %%
sns.stripplot(x= 'day',y="tip",data=tips, size=10,jitter=False)
plt.ylabel("tip($)")
plt.show()

# %%
sns.stripplot(x= 'day',y="tip",data=tips,hue ='day',size=10)
plt.ylabel("tip($)")
plt.show()

# %%
sns.stripplot(x= 'day',y="tip",data=tips,hue ='day')
plt.ylabel("tip($)")
plt.show()

# %%
sns.swarmplot(x= 'day',y="tip",data=tips,hue ='day',size=6)
plt.ylabel("tip($)")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ab=sns.swarmplot(x= 'day',y="tip",data=tips,hue ='sex',size=6)
ab.set_xlabel("Day")
ab.set_ylabel("Tip")
ab.set_title("Graph")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Graph')

# %%
ab=sns.swarmplot(x= 'day',y="tip",data=tips,hue ='time',size=6)
ab.set_xlabel("Day")
ab.set_ylabel("Tip")
ab.set_title("Graph")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Graph')

# %%
ab=sns.swarmplot(y= 'day',x="tip",data=tips,hue ='time',size=6,orient="h")
ab.set_xlabel("Day")
ab.set_ylabel("Tip")
ab.set_title("Graph")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Graph')

# %%
sns.swarmplot(y= 'day',x="tip",data=tips,hue ='time',size=6,orient="h")
plt.xlabel("tip($)")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.boxplot(x='day',y= 'tip',data=tips)
plt.ylabel('tips($)')
plt.title('Boxlpot of tips')

plt.subplot(1,2,2)
sns.violinplot(x='day',y= 'tip',data=tips)
plt.ylabel('tips($)')
plt.title('Violin of tips')
# Out:
# Text(0.5, 1.0, 'Violin of tips')

# %%
sns.violinplot(x='day',y='tip',data=tips,inner=None,color='lightgray')  #inner{“box”, “quartile”, “point”, “stick”, None}, optional
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.ylabel('tip($)')
# Out:
# Text(0, 0.5, 'tip($)')

# %%
sns.violinplot(x='day',y='tip',data=tips,inner='box',color='lightgray')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.ylabel('tip($)')
# Out:
# Text(0, 0.5, 'tip($)')

# %%
sns.violinplot(x='day',y='tip',data=tips,inner='stick',color='lightgray')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.ylabel('tip($)')
# Out:
# Text(0, 0.5, 'tip($)')

# %%
sns.violinplot(x='day',y='tip',data=tips,inner='point',color='lightgray')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.ylabel('tip($)')
# Out:
# Text(0, 0.5, 'tip($)')

# %%
sns.violinplot(x='day',y='tip',data=tips,inner='quartile',color='lightgray')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.ylabel('tip($)')
# Out:
# Text(0, 0.5, 'tip($)')

# %%
sns.scatterplot(tips['total_bill'],tips['tip'])   #the tip amount is incresing with the total_bill amount
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tips['total_bill'],tips['tip'],hue=tips['time'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x= 'total_bill',y = 'tip', data= tips)
plt.show()

# %%
sns.jointplot(x= 'total_bill',y = 'tip', data= tips,kind='kde')

# %%
sns.jointplot(x= 'total_bill',y = 'tip', data= tips,kind='kde',hue=tips['time']) #kernel density point
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,kind="kde")
plt.show()

# %%
sns.pairplot(tips,diag_kind="kde")
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %%
sns.pairplot(tips, hue='time')
plt.show()

# %%
sns.pairplot(tips, hue='smoker')
plt.show()

# %%
sns.pairplot(tips, hue='day')
plt.show()

# %%
df=pd.read_csv("C:/Users/user/Desktop/Data Science/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby('Survived')["PassengerId"].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
df.groupby(['Survived',"Sex"])["PassengerId"].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: PassengerId, dtype: int64

# %%
pd.crosstab(df["Survived"],df["Sex"])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df["Survived"],df["Sex"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
pd.crosstab(df["Sex"],df["Survived"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
pd.crosstab(df["Survived"],df["Pclass"]).count()
# Out:
# Pclass
# 1    2
# 2    2
# 3    2
# dtype: int64

# %%
pd.crosstab(df["Survived"],df["Pclass"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
pd.crosstab(df["Survived"],df["Pclass"]).count()
# Out:
# Pclass
# 1    2
# 2    2
# 3    2
# dtype: int64

# %%
pd.crosstab(df["Pclass"],df["Survived"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
pd.crosstab(df["Pclass"],[df.Sex,df["Survived"]]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
sns.boxplot(x="Survived",y="Age",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x="Sex",y="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(x="Sex",y="Age",hue="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x="Survived",y="Age",hue="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x="Pclass",y="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x="Pclass",y="Survived",hue="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x="SibSp",y="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
sns.barplot(x="Parch",y="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %%
df.loc[df['Survived']==1,"Age"]
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
df.loc[df['Survived']==1,"Age"].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 8      False
# 9      False
#        ...
# 875    False
# 879    False
# 880    False
# 887    False
# 889    False
# Name: Age, Length: 342, dtype: bool

# %%
df.loc[df['Survived']==1,"Age"].isnull().sum()
# Out:
# 52

# %%
survived=df.loc[df['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Survived')

# %%
not_survived=df.loc[df['Survived']==0,"Age"].dropna()
sns.distplot(not_survived,color="purple")
plt.title("Not Survived")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Not Survived')

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['Age'].dropna(),bins = 10,stat='count')   #stat=count,frequency,density,probability,percent
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'].dropna(),bins = 10,stat='frequency')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Frequency'>

# %%
sns.histplot(df['Age'].dropna(),bins = 10,stat='probability')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Probability'>

# %%
sns.histplot(df['Age'].dropna(),bins = 10,stat='percent')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Percent'>

# %%
sns.histplot(df['Age'].dropna(),bins = 10,stat='density')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(df.dropna())

# %%
figbi, axesbi = plt.subplots(2,4,figsize=(16,6))
df.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
df.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
df.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
df.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
df.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x='Survived',y='Age',data=df,ax=axesbi[1,1])
sns.boxplot(x='Survived',y='Fare',data=df,ax=axesbi[1,2])
figbi.savefig("mylstfig.png")
plt.show()

# %%
sns.boxplot(y='Survived',x='Fare',data=df,orient="h")
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Survived'>

# %%
df.groupby("Survived")["Fare"].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
from scipy  import stats

# %%
stats.norm.cdf(2.8)
# Out:
# 0.997444869669572

# %%
1-stats.norm.cdf(2.8)
# Out:
# 0.0025551303304279793

# %%
stats.norm.cdf(2.1)-stats.norm.cdf(1.6)
# Out:
# 0.03693487113674143

# %%
stats.norm.cdf(8,loc = 5, scale=4)    #z score for standard normal dist
# Out:
# 0.7733726476231317

# %%
1-stats.norm.cdf(0.75)
# Out:
# 0.22662735237686826

# %%
1-stats.norm.cdf(8,loc = 5, scale=4)
# Out:
# 0.22662735237686826

# %%
stats.norm.ppf(0.683)
# Out:
# 0.4761044034893952

# %%
stats.norm.cdf(0.4761)
# Out:
# 0.6829984314963362

# %%
stats.norm.cdf(25,loc = 20, scale=7)
# Out:
# 0.7624747379730235

# %%
stats.norm.ppf(0.7624,20,7)
# Out:
# 24.998307685001286

# %%
stats.norm.ppf(0.1948,75,7)
# Out:
# 68.97759904733479

# %%
stats.norm.cdf(68.9775,loc = 75, scale=7)
# Out:
# 0.1947961012809012

# %%
stats.norm.ppf(1-0.1948,75,7)
# Out:
# 81.02240095266521

# %%
1-stats.norm.cdf(81.02240095266521,loc = 75, scale=7)
# Out:
# 0.19479999999999986
